# %% [markdown]
# <a href="https://colab.research.google.com/github/AchinthaThennakoon/L4S2-FYP-UOM/blob/main/Final_v1/hybrid_model/with_loading%20fine_tuned_models%20/hybrid_model_(fine_tuned_fe_cnn_%2B_vit_b16)_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers,models
from tensorflow.keras.models import Sequential

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %%
import pathlib

# %%
import tensorflow_hub as hub

# %%
import os

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# !pip install vit-keras
# Out:
# Collecting vit-keras
#   Downloading vit_keras-0.1.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from vit-keras) (1.11.4)
# Collecting validators (from vit-keras)
#   Downloading validators-0.33.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->vit-keras) (1.25.2)
# Downloading vit_keras-0.1.2-py3-none-any.whl (24 kB)
# Downloading validators-0.33.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: validators, vit-keras
# Successfully installed validators-0.33.0 vit-keras-0.1.2

# %%
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (24.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 31.0 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3

# %%
from vit_keras import vit
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# # loading data set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train'

# %%
data_dir = pathlib.Path(dataset_path)
data_dir
# Out:
# PosixPath('/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train')

# %%
train_ds,val_ds =  keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.3,
    subset="both",
    seed=123,
    batch_size=32,
    image_size=(224, 224),
    )
# Out:
# Found 4701 files belonging to 4 classes.
# Using 3291 files for training.
# Using 1410 files for validation.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['Cercospora Leaf Spot', 'Common Rust', 'Healthy', 'Northern Leaf Blight']

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in train_ds.take(1):
    for i in range(8):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ## divide validation set to test & validation

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(val_ds))
# Out:
# Number of validation batches: 45

# %%
val_batches = tf.data.experimental.cardinality(val_ds)
test_dataset = val_ds.take(val_batches // 2)
validation_dataset = val_ds.skip(val_batches // 2)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 23
# Number of test batches: 22

# %% [markdown]
# # Custom Layers

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2)
])

# %%
rescale = tf.keras.layers.Rescaling(1./127.5, offset=-1)

# %% [markdown]
# # Hybrid model 1

# %%
def create_hybrid_model_with_pretrained_vit(input_shape, num_classes, vit_feature_extractor,cnn_model):
    # Input layer
    inputs = layers.Input(shape=input_shape)

    # Data augmentation and rescaling
    x = data_augmentation(inputs)
    x = rescale(x)

    # Pretrained ViT feature extractor
    vit_features = vit_feature_extractor(x, training=False)
    vit_features = layers.Flatten()(vit_features)  # Ensure it is flattened for concatenation


    # Custom CNN component
    cnn_features = cnn_model(inputs)

    # Concatenate the outputs of ViT and CNN
    combined_features = layers.Concatenate()([vit_features, cnn_features])

    # Fully connected layers
    x = layers.Dense(1024, activation='relu')(combined_features)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='leaky_relu')(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)

    # Output layer
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    # Create and compile model
    hybrid_model = models.Model(inputs=inputs, outputs=outputs)
    hybrid_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    hybrid_model.summary()
    return hybrid_model

# %% [markdown]
# ## Train hybrid model 1

# %%
input_shape = (224,224,3)
num_classes = len(class_names)
epochs = 150

# %% [markdown]
# ## CNN feature extractor

# %%
cnn_model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/FYP_code/Final_v1/CNN_model_selecting/custom_CNN/models/custom_cnn_model_depth_4_all_diseases.keras')
cnn_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential_2 (Sequential)   (None, 224, 224, 3)       0
#
#  sequential_3 (Sequential)   (None, 224, 224, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_4 (MaxPoolin  (None, 111, 111, 32)      0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 52, 52, 64)        36928
#
#  max_pooling2d_6 (MaxPoolin  (None, 26, 26, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 64)        36928
#
#  max_pooling2d_7 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 64)                589888
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 683396 (2.61 MB)
# Trainable params: 683396 (2.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Remove the classification layer to create a feature extractor
cnn_fe = models.Model(inputs=cnn_model.input, outputs=cnn_model.layers[-3].output)
cnn_fe.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential_2 (Sequential)   (None, 224, 224, 3)       0
#
#  sequential_3 (Sequential)   (None, 224, 224, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_4 (MaxPoolin  (None, 111, 111, 32)      0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 52, 52, 64)        36928
#
#  max_pooling2d_6 (MaxPoolin  (None, 26, 26, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 64)        36928
#
#  max_pooling2d_7 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
# =================================================================
# Total params: 93248 (364.25 KB)
# Trainable params: 93248 (364.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## vit feature extractor

# %%
vit_model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/FYP_code/Final_v1/ViT_model_selecting/vit_b16/models/vit_b16_model.keras',safe_mode=False)
vit_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  vit-b16 (Functional)        (None, 768)               85798656
#
#  dropout (Dropout)           (None, 768)               0
#
#  dense (Dense)               (None, 4)                 3076
#
# =================================================================
# Total params: 85801732 (327.31 MB)
# Trainable params: 85801732 (327.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
vit_fe = models.Model(inputs=vit_model.input, outputs=vit_model.layers[-2].output)
vit_fe.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  vit-b16 (Functional)        (None, 768)               85798656
#
#  dropout (Dropout)           (None, 768)               0
#
# =================================================================
# Total params: 85798656 (327.30 MB)
# Trainable params: 85798656 (327.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
num_classes
# Out:
# 4

# %%
hybrid_model = create_hybrid_model_with_pretrained_vit(input_shape, num_classes, vit_fe,cnn_fe)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  sequential (Sequential)     (None, 224, 224, 3)          0         ['input_1[0][0]']
#
#  rescaling (Rescaling)       (None, 224, 224, 3)          0         ['sequential[0][0]']
#
#  model_1 (Functional)        (None, 768)                  8579865   ['rescaling[0][0]']
#                                                           6
#
#  flatten (Flatten)           (None, 768)                  0         ['model_1[0][0]']
#
#  model (Functional)          (None, 9216)                 93248     ['input_1[0][0]']
#
#  concatenate (Concatenate)   (None, 9984)                 0         ['flatten[0][0]',
#                                                                      'model[0][0]']
#
#  dense (Dense)               (None, 1024)                 1022464   ['concatenate[0][0]']
#                                                           0
#
#  dropout_36 (Dropout)        (None, 1024)                 0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  262400    ['dropout_36[0][0]']
#
#  dropout_37 (Dropout)        (None, 256)                  0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  32896     ['dropout_37[0][0]']
#
#  dropout_38 (Dropout)        (None, 128)                  0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 4)                    516       ['dropout_38[0][0]']
#
# ==================================================================================================
# Total params: 96412356 (367.78 MB)
# Trainable params: 96412356 (367.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min',restore_best_weights=True)

# %%
model_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Final_v1/hybrid_model/trained_hybrid_models'

# %%
def runExperiment(train_ds, validation_ds, test_ds, input_shape, num_classes, hybrid_model, epochs):

    # Train the model
    history = hybrid_model.fit(
        train_ds,
        validation_data=validation_ds,
        verbose=1,
        epochs=epochs,
        callbacks=[early_stopping],
        batch_size=32
    )

    hybrid_model.save(os.path.join(model_path, f'hybrid_model_(fine tuned fe cnn + vit_b16)_v4.keras'))

    # Evaluate the model
    test_loss, test_accuracy = hybrid_model.evaluate(test_ds)
    print(f'Test accuracy: {test_accuracy}')

    return history, test_loss, test_accuracy

# %%
history, test_loss, test_accuracy = runExperiment(train_ds, validation_dataset, test_dataset, input_shape, num_classes, hybrid_model, epochs)
# Out:
# Epoch 1/150
# 103/103 [==============================] - 1664s 16s/step - loss: 0.2234 - accuracy: 0.9313 - val_loss: 0.0650 - val_accuracy: 0.9802
# Epoch 2/150
# 103/103 [==============================] - 142s 1s/step - loss: 0.0959 - accuracy: 0.9708 - val_loss: 0.0796 - val_accuracy: 0.9717
# Epoch 3/150
# 103/103 [==============================] - 140s 1s/step - loss: 0.0992 - accuracy: 0.9696 - val_loss: 0.0693 - val_accuracy: 0.9773
# Epoch 4/150
# 103/103 [==============================] - 141s 1s/step - loss: 0.1347 - accuracy: 0.9602 - val_loss: 0.0678 - val_accuracy: 0.9703
# Epoch 5/150
# 103/103 [==============================] - 149s 1s/step - loss: 0.0805 - accuracy: 0.9723 - val_loss: 0.0376 - val_accuracy: 0.9901
# Epoch 6/150
# 103/103 [==============================] - 149s 1s/step - loss: 0.0615 - accuracy: 0.9818 - val_loss: 0.0832 - val_accuracy: 0.9703
# Epoch 7/150
# 103/103 [==============================] - 140s 1s/step - loss: 0.0644 - accuracy: 0.9796 - val_loss: 0.0789 - val_accuracy: 0.9703
# Epoch 8/150
# 103/103 [==============================] - 141s 1s/step - loss: 0.0860 - accuracy: 0.9757 - val_loss: 0.0947 - val_accuracy: 0.9674
# Epoch 9/150
# 103/103 [==============================] - 140s 1s/step - loss: 0.0772 - accuracy: 0.9754 - val_loss: 0.0319 - val_accuracy: 0.9915
# Epoch 10/150
# 103/103 [==============================] - 141s 1s/step - loss: 0.0991 - accuracy: 0.9720 - val_loss: 0.0623 - val_accuracy: 0.9731
# Epoch 11/150
# 103/103 [==============================] - 141s 1s/step - loss: 0.1059 - accuracy: 0.9696 - val_loss: 0.0668 - val_accuracy: 0.9773
# Epoch 12/150
# 103/103 [==============================] - 149s 1s/step - loss: 0.0676 - accuracy: 0.9787 - val_loss: 0.0566 - val_accuracy: 0.9802
# Epoch 13/150
# 103/103 [==============================] - 149s 1s/step - loss: 0.0672 - accuracy: 0.9802 - val_loss: 0.0381 - val_accuracy: 0.9873
# Epoch 14/150
# 103/103 [==============================] - 141s 1s/step - loss: 0.0475 - accuracy: 0.9839 - val_loss: 0.0371 - val_accuracy: 0.9858
# 22/22 [==============================] - 10s 426ms/step - loss: 0.0566 - accuracy: 0.9815
# Test accuracy: 0.9815340638160706

# %%
def plot_history(item):
    plt.plot(history.history[item], label=item)
    plt.plot(history.history["val_" + item], label="val_" + item)
    plt.xlabel("Epochs")
    plt.ylabel(item)
    plt.title("Train and Validation {} Over Epochs".format(item), fontsize=14)
    plt.legend()
    plt.grid()
    plt.show()


plot_history("loss")
plot_history("accuracy")

# %% [markdown]
# # Confusion matrix

# %%
predictions = hybrid_model.predict(test_dataset)
predictions
# Out:
# 22/22 [==============================] - 10s 432ms/step
# array([[5.8779967e-01, 4.7355148e-04, 1.7667140e-06, 4.1172507e-01],
#        [6.7486950e-27, 1.0000000e+00, 2.6173537e-34, 1.4657778e-21],
#        [2.6699743e-01, 8.7069444e-02, 2.1827271e-02, 6.2410587e-01],
#        ...,
#        [9.2319016e-07, 1.5859003e-07, 9.9999702e-01, 1.9499960e-06],
#        [1.2728119e-18, 1.0000000e+00, 1.3456006e-23, 1.8261390e-14],
#        [8.0607991e-16, 1.0000000e+00, 1.1258729e-19, 4.1742777e-12]],
#       dtype=float32)

# %%
y_pred_classes = np.argmax(predictions, axis=1)
y_pred_classes

# %%
y_true = np.concatenate([y for x, y in test_dataset], axis=0)
y_true
# Out:
# array([0, 1, 3, 2, 0, 1, 0, 1, 0, 3, 0, 1, 3, 1, 0, 3, 1, 3, 3, 1, 3, 1,
#        1, 3, 1, 3, 1, 1, 3, 1, 1, 3, 1, 1, 3, 3, 1, 2, 0, 1, 3, 1, 1, 1,
#        1, 3, 1, 2, 1, 3, 1, 2, 1, 3, 3, 2, 3, 2, 1, 0, 1, 1, 3, 2, 3, 3,
#        1, 1, 1, 3, 3, 1, 0, 3, 3, 1, 2, 1, 3, 3, 1, 3, 3, 1, 1, 1, 1, 2,
#        3, 0, 1, 3, 1, 3, 1, 3, 0, 3, 2, 1, 0, 3, 1, 3, 2, 0, 3, 3, 3, 1,
#        1, 3, 1, 1, 1, 1, 0, 1, 3, 2, 3, 3, 3, 2, 3, 2, 3, 2, 1, 1, 3, 3,
#        3, 0, 1, 0, 3, 3, 0, 3, 1, 1, 3, 0, 1, 1, 1, 1, 3, 3, 1, 2, 0, 3,
#        0, 3, 0, 0, 1, 3, 3, 1, 0, 3, 1, 3, 1, 0, 1, 1, 0, 1, 0, 1, 3, 1,
#        1, 1, 1, 1, 0, 3, 1, 0, 0, 1, 2, 0, 1, 3, 1, 3, 3, 1, 3, 1, 3, 1,
#        1, 2, 1, 3, 0, 3, 0, 2, 2, 3, 3, 1, 1, 1, 3, 0, 3, 3, 0, 1, 1, 0,
#        1, 1, 1, 1, 1, 1, 3, 1, 3, 1, 0, 1, 1, 2, 0, 0, 0, 3, 1, 0, 3, 3,
#        1, 3, 1, 2, 0, 3, 0, 3, 1, 0, 3, 3, 0, 3, 3, 3, 3, 1, 3, 0, 1, 3,
#        0, 1, 1, 1, 3, 1, 1, 2, 1, 1, 2, 2, 1, 3, 0, 3, 3, 1, 3, 3, 3, 1,
#        0, 1, 3, 1, 3, 3, 0, 3, 1, 2, 1, 2, 3, 3, 3, 1, 3, 1, 3, 3, 3, 1,
#        3, 3, 1, 3, 3, 3, 1, 3, 1, 0, 3, 3, 3, 3, 3, 0, 1, 3, 1, 0, 1, 3,
#        0, 1, 3, 3, 1, 0, 1, 2, 0, 0, 3, 1, 1, 2, 3, 1, 3, 0, 1, 3, 3, 1,
#        1, 3, 1, 1, 2, 1, 3, 1, 3, 1, 1, 1, 3, 1, 2, 1, 2, 3, 1, 3, 1, 1,
#        0, 3, 3, 0, 3, 1, 3, 2, 1, 3, 2, 1, 3, 3, 3, 0, 1, 1, 1, 1, 3, 3,
#        1, 1, 1, 3, 3, 0, 3, 3, 1, 1, 1, 3, 1, 3, 1, 1, 3, 3, 3, 3, 3, 1,
#        1, 0, 3, 1, 1, 1, 1, 1, 3, 3, 3, 3, 1, 3, 3, 3, 1, 1, 1, 1, 1, 2,
#        1, 3, 3, 3, 3, 3, 3, 1, 3, 0, 3, 0, 3, 1, 1, 3, 3, 1, 2, 1, 3, 0,
#        3, 3, 1, 3, 1, 1, 1, 3, 1, 3, 3, 1, 1, 2, 3, 1, 0, 1, 3, 3, 1, 0,
#        1, 0, 3, 0, 3, 3, 1, 1, 1, 1, 3, 0, 2, 3, 3, 3, 2, 0, 1, 1, 1, 3,
#        3, 3, 3, 3, 2, 3, 1, 1, 1, 1, 3, 1, 1, 3, 1, 1, 3, 2, 3, 3, 3, 3,
#        2, 3, 0, 3, 1, 3, 3, 0, 1, 1, 3, 3, 3, 3, 3, 3, 1, 2, 0, 1, 3, 0,
#        0, 1, 3, 2, 1, 3, 0, 1, 3, 3, 3, 1, 3, 1, 3, 2, 3, 0, 2, 3, 1, 1,
#        1, 1, 0, 3, 3, 3, 1, 1, 3, 1, 1, 3, 1, 1, 3, 1, 3, 3, 1, 1, 2, 3,
#        1, 1, 3, 2, 0, 3, 1, 3, 1, 3, 3, 3, 3, 3, 3, 1, 1, 3, 1, 1, 1, 3,
#        0, 1, 3, 2, 1, 1, 1, 3, 1, 0, 1, 1, 1, 1, 1, 1, 1, 3, 1, 3, 3, 0,
#        3, 2, 0, 3, 3, 3, 1, 1, 2, 3, 3, 1, 1, 2, 1, 1, 1, 3, 1, 0, 3, 3,
#        0, 3, 1, 3, 1, 3, 0, 1, 3, 1, 1, 3, 3, 1, 3, 3, 3, 3, 3, 2, 1, 3,
#        1, 1, 3, 1, 3, 1, 1, 3, 3, 1, 3, 1, 1, 0, 0, 3, 3, 1, 1, 2, 1, 1],
#       dtype=int32)

# %%
cm = confusion_matrix(y_true, y_pred_classes)

# Create a larger figure
fig, ax = plt.subplots(figsize=(10, 10))

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, ax=ax)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
#                       precision    recall  f1-score   support
#
# Cercospora Leaf Spot       0.92      0.96      0.94        89
#          Common Rust       0.99      1.00      0.99       282
#              Healthy       0.96      1.00      0.98        54
# Northern Leaf Blight       1.00      0.97      0.98       279
#
#             accuracy                           0.98       704
#            macro avg       0.97      0.98      0.97       704
#         weighted avg       0.98      0.98      0.98       704

# %% [markdown]
# # show incorrectly classified images

# %%
# Find incorrectly classified images
incorrect_indices = np.where(y_pred_classes != y_true)[0]
incorrect_indices
# Out:
# array([ 29, 116, 126, 183, 237, 257, 323, 386, 409, 429, 483, 533, 555])

# %%
# Get the images and labels
images = np.concatenate([x for x, y in test_dataset], axis=0)
incorrect_images = images[incorrect_indices]
incorrect_true_labels = y_true[incorrect_indices]
incorrect_pred_labels = y_pred_classes[incorrect_indices]

# %%
# Display incorrectly classified images
num_images_to_display = 10  # Number of images to display
plt.figure(figsize=(15, 15))
for i in range(min(num_images_to_display, len(incorrect_images))):
    plt.subplot(5, 2, i + 1)
    plt.imshow(incorrect_images[i].astype("uint8"))
    plt.title(f"True: {class_names[incorrect_true_labels[i]]}, Pred: {class_names[incorrect_pred_labels[i]]}")
    plt.axis("off")
plt.show()

# %% [markdown]
# leaf spot : Mature lesions from gray leaf spot are rectangular, as they are restricted by the leaf veins.
#
# leaf blight : Northern corn leaf blight is easily identified by the 1- to 6-inch cigar-shaped lesions on lower leaves, which may be grayish-green to tan in color.

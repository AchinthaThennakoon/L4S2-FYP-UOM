# %% [markdown]
# <a href="https://colab.research.google.com/github/AchinthaThennakoon/L4S2-FYP-UOM/blob/main/Final_v1/ViT_model_selecting/vit_b32/vit_b32(all_diseases).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# %%
import pandas as pd

# %%
import pickle

# %%
import json
import os

# %%
import numpy as np

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# !pip install vit-keras
# Out:
# Collecting vit-keras
#   Downloading vit_keras-0.1.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from vit-keras) (1.11.4)
# Collecting validators (from vit-keras)
#   Downloading validators-0.33.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->vit-keras) (1.25.2)
# Installing collected packages: validators, vit-keras
# Successfully installed validators-0.33.0 vit-keras-0.1.2

# %%
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (24.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3

# %%
from vit_keras import vit
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# # loading data set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train'

# %%
data_dir = pathlib.Path(dataset_path)
data_dir
# Out:
# PosixPath('/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train')

# %%
train_ds,val_ds =  keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.3,
    subset="both",
    seed=123,
    shuffle=True,
    batch_size=32,
    image_size=(224, 224),
    )
# Out:
# Found 7326 files belonging to 4 classes.
# Using 5129 files for training.
# Using 2197 files for validation.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['Cercospora Leaf Spot', 'Common Rust', 'Healthy', 'Northern Leaf Blight']

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in train_ds.take(1):
    for i in range(8):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ## divide validation set to test & validation

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(val_ds))
# Out:
# Number of validation batches: 69

# %%
val_batches = tf.data.experimental.cardinality(val_ds)
test_dataset = val_ds.take(val_batches // 2)
validation_dataset = val_ds.skip(val_batches // 2)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 35
# Number of test batches: 34

# %% [markdown]
# # parameters and augmentations

# %%
resize_and_rescale = keras.Sequential([
  keras.layers.Resizing(224, 224),
  keras.layers.Rescaling(1./127.5, offset=-1),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2)
])

# %%
no_of_classes = len(class_names)
no_of_classes
# Out:
# 4

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS=3

# %%
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

# %%
epochs = 150

# %% [markdown]
# # Loading base model

# %%
# Load a pre-trained ViT model without the top classification layer
vit_model = vit.vit_b32(
    image_size=IMAGE_SIZE,
    pretrained=True,
    include_top=False,
    pretrained_top=False
)
# Out:
# Downloading data from https://github.com/faustomorales/vit-keras/releases/download/dl/ViT-B_32_imagenet21k+imagenet2012.npz
# 353253686/353253686 [==============================] - 2s 0us/step
# /usr/local/lib/python3.10/dist-packages/vit_keras/utils.py:81: UserWarning: Resizing position embeddings from 12, 12 to 7, 7
#   warnings.warn(

# %% [markdown]
# # model

# %%
def create_model():
  inputs = tf.keras.Input(shape=input_shape)
  x = resize_and_rescale(inputs)
  x = data_augmentation(x)
  x = vit_model(x, training=False)
  x = tf.keras.layers.Dropout(0.2)(x)
  outputs = layers.Dense(no_of_classes, activation='softmax')(x)
  model = tf.keras.Model(inputs, outputs)
  model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  model.summary()
  return model

# %% [markdown]
# ## Early stopping

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
                                                    monitor='val_loss',
                                                    mode='min',
                                                    patience=5,
                                                    restore_best_weights=True
                                                    )

# %% [markdown]
# # Training, Save and evaluation functions

# %%
model_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Final_v1/ViT_model_selecting/vit_b32/models'

# %%
model = create_model()
history = model.fit(
                    train_ds,
                    batch_size=BATCH_SIZE,
                    validation_data=validation_dataset,
                    verbose=1,
                    epochs=epochs,
                    callbacks=[early_stopping]
                    )

model.save(os.path.join(model_path, f'vit_b16_model.keras'))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  vit-b32 (Functional)        (None, 768)               87455232
#
#  dropout (Dropout)           (None, 768)               0
#
#  dense (Dense)               (None, 4)                 3076
#
# =================================================================
# Total params: 87458308 (333.63 MB)
# Trainable params: 87458308 (333.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/150
# 161/161 [==============================] - 765s 4s/step - loss: 0.6007 - accuracy: 0.7536 - val_loss: 0.2950 - val_accuracy: 0.8801
# Epoch 2/150
# 161/161 [==============================] - 71s 438ms/step - loss: 0.2203 - accuracy: 0.9169 - val_loss: 0.1767 - val_accuracy: 0.9342
# Epoch 3/150
# 161/161 [==============================] - 71s 432ms/step - loss: 0.1437 - accuracy: 0.9415 - val_loss: 0.1716 - val_accuracy: 0.9378
# Epoch 4/150
# 161/161 [==============================] - 72s 438ms/step - loss: 0.1429 - accuracy: 0.9483 - val_loss: 0.1516 - val_accuracy: 0.9477
# Epoch 5/150
# 161/161 [==============================] - 71s 439ms/step - loss: 0.1209 - accuracy: 0.9575 - val_loss: 0.5222 - val_accuracy: 0.8314
# Epoch 6/150
# 161/161 [==============================] - 71s 432ms/step - loss: 0.1201 - accuracy: 0.9571 - val_loss: 0.1932 - val_accuracy: 0.9216
# Epoch 7/150
# 161/161 [==============================] - 69s 423ms/step - loss: 0.1177 - accuracy: 0.9608 - val_loss: 0.0977 - val_accuracy: 0.9639
# Epoch 8/150
# 161/161 [==============================] - 71s 435ms/step - loss: 0.0999 - accuracy: 0.9647 - val_loss: 0.1253 - val_accuracy: 0.9585
# Epoch 9/150
# 161/161 [==============================] - 71s 434ms/step - loss: 0.0973 - accuracy: 0.9659 - val_loss: 0.0943 - val_accuracy: 0.9657
# Epoch 10/150
# 161/161 [==============================] - 69s 426ms/step - loss: 0.0979 - accuracy: 0.9630 - val_loss: 0.1070 - val_accuracy: 0.9657
# Epoch 11/150
# 161/161 [==============================] - 70s 428ms/step - loss: 0.0845 - accuracy: 0.9702 - val_loss: 0.0948 - val_accuracy: 0.9666
# Epoch 12/150
# 161/161 [==============================] - 68s 420ms/step - loss: 0.0928 - accuracy: 0.9659 - val_loss: 0.0844 - val_accuracy: 0.9684
# Epoch 13/150
# 161/161 [==============================] - 70s 428ms/step - loss: 0.0962 - accuracy: 0.9653 - val_loss: 0.1417 - val_accuracy: 0.9603
# Epoch 14/150
# 161/161 [==============================] - 69s 426ms/step - loss: 0.0860 - accuracy: 0.9676 - val_loss: 0.0734 - val_accuracy: 0.9757
# Epoch 15/150
# 161/161 [==============================] - 71s 435ms/step - loss: 0.0877 - accuracy: 0.9690 - val_loss: 0.0857 - val_accuracy: 0.9684
# Epoch 16/150
# 161/161 [==============================] - 69s 424ms/step - loss: 0.0788 - accuracy: 0.9708 - val_loss: 0.0600 - val_accuracy: 0.9784
# Epoch 17/150
# 161/161 [==============================] - 70s 428ms/step - loss: 0.0665 - accuracy: 0.9768 - val_loss: 0.0929 - val_accuracy: 0.9693
# Epoch 18/150
# 161/161 [==============================] - 70s 428ms/step - loss: 0.0923 - accuracy: 0.9659 - val_loss: 0.1092 - val_accuracy: 0.9621
# Epoch 19/150
# 161/161 [==============================] - 70s 429ms/step - loss: 0.0673 - accuracy: 0.9752 - val_loss: 0.0793 - val_accuracy: 0.9729
# Epoch 20/150
# 161/161 [==============================] - 68s 418ms/step - loss: 0.0749 - accuracy: 0.9731 - val_loss: 0.0830 - val_accuracy: 0.9757
# Epoch 21/150
# 161/161 [==============================] - 69s 426ms/step - loss: 0.0811 - accuracy: 0.9708 - val_loss: 0.1192 - val_accuracy: 0.9585

# %%
test_loss, test_acc = model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 5s 151ms/step - loss: 0.0602 - accuracy: 0.9724

# %%
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# Test accuracy: 0.9724264740943909
# Test loss: 0.06021391600370407

# %% [markdown]
# # loading model(if needed)

# %%
#model = create_model()

# %%
#model = tf.keras.models.load_model(os.path.join(model_path, f'vit_b16_model.keras'), safe_mode=False)

# %% [markdown]
# # predictions

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 5s 139ms/step - loss: 0.0602 - accuracy: 0.9724
# [0.06021391600370407, 0.9724264740943909]

# %%
predictions = model.predict(test_dataset)
# Out:
# 34/34 [==============================] - 9s 140ms/step

# %%
predictions
# Out:
# array([[9.9918836e-01, 6.5902699e-05, 1.1918474e-05, 7.3385035e-04],
#        [1.2945848e-05, 9.9998617e-01, 4.4456877e-07, 4.1223822e-07],
#        [3.6900113e-03, 3.3434251e-05, 1.7154385e-05, 9.9625945e-01],
#        ...,
#        [2.9311571e-04, 4.5422879e-05, 9.9845326e-01, 1.2082114e-03],
#        [1.6117166e-03, 2.3617868e-04, 5.9864709e-05, 9.9809223e-01],
#        [1.8586939e-04, 9.9980754e-01, 4.9135942e-06, 1.7033900e-06]],
#       dtype=float32)

# %%
y_pred_classes = np.argmax(predictions, axis=1)
y_pred_classes
# Out:
# array([0, 1, 3, ..., 2, 3, 1])

# %%
y_true = np.concatenate([y for x, y in test_dataset], axis=0)
y_true
# Out:
# array([0, 1, 3, ..., 2, 3, 1], dtype=int32)

# %%
import collections
counter = collections.Counter(y_true)
print(counter)
# Out:
# Counter({3: 297, 1: 295, 2: 269, 0: 227})

# %%
cm = confusion_matrix(y_true, y_pred_classes)

# Create a larger figure
fig, ax = plt.subplots(figsize=(10, 10))

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, ax=ax)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
#                       precision    recall  f1-score   support
#
# Cercospora Leaf Spot       0.90      0.98      0.94       227
#          Common Rust       0.99      0.98      0.99       295
#              Healthy       1.00      1.00      1.00       269
# Northern Leaf Blight       0.99      0.93      0.96       297
#
#             accuracy                           0.97      1088
#            macro avg       0.97      0.97      0.97      1088
#         weighted avg       0.97      0.97      0.97      1088

# %% [markdown]
# # show incorrectly classified images

# %%
# Find incorrectly classified images
incorrect_indices = np.where(y_pred_classes != y_true)[0]
incorrect_indices
# Out:
# array([  14,   42,   60,   69,   97,  116,  234,  256,  258,  424,  426,
#         427,  428,  489,  507,  519,  526,  530,  623,  635,  660,  742,
#         779,  871,  878,  982,  984, 1036, 1042, 1079])

# %%
# Get the images and labels
images = np.concatenate([x for x, y in test_dataset], axis=0)
incorrect_images = images[incorrect_indices]
incorrect_true_labels = y_true[incorrect_indices]
incorrect_pred_labels = y_pred_classes[incorrect_indices]

# %%
# Display incorrectly classified images
num_images_to_display = 10  # Number of images to display
plt.figure(figsize=(15, 15))
for i in range(min(num_images_to_display, len(incorrect_images))):
    plt.subplot(5, 2, i + 1)
    plt.imshow(incorrect_images[i].astype("uint8"))
    plt.title(f"True: {class_names[incorrect_true_labels[i]]}, Pred: {class_names[incorrect_pred_labels[i]]}")
    plt.axis("off")
plt.show()

# %% [markdown]
# leaf spot : Mature lesions from gray leaf spot are rectangular, as they are restricted by the leaf veins.
#
# leaf blight : Northern corn leaf blight is easily identified by the 1- to 6-inch cigar-shaped lesions on lower leaves, which may be grayish-green to tan in color.

# %% [markdown]
# <a href="https://colab.research.google.com/github/AchinthaThennakoon/L4S2-FYP-UOM/blob/main/Final_v1/CNN_model_selecting/VGG16/VGG16(all_diseases).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# %%
import pandas as pd

# %%
import pickle

# %%
import json
import os

# %%
import numpy as np

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
import tensorflow_hub as hub

# %% [markdown]
# # loading data set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train'

# %%
data_dir = pathlib.Path(dataset_path)
data_dir
# Out:
# PosixPath('/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train')

# %%
train_ds,val_ds =  keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.3,
    subset="both",
    seed=123,
    shuffle=True,
    batch_size=32,
    image_size=(224, 224),
    )
# Out:
# Found 7326 files belonging to 4 classes.
# Using 5129 files for training.
# Using 2197 files for validation.

# %%
for batch in train_ds.take(1):
    images, labels = batch
    print(images.shape)  # Should be (32, 224, 224, 3) if batch size is 32
    print(labels.shape)
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['Cercospora Leaf Spot', 'Common Rust', 'Healthy', 'Northern Leaf Blight']

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in train_ds.take(1):
    for i in range(8):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ## divide validation set to test & validation

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(val_ds))
# Out:
# Number of validation batches: 69

# %%
val_batches = tf.data.experimental.cardinality(val_ds)
test_dataset = val_ds.take(val_batches // 2)
validation_dataset = val_ds.skip(val_batches // 2)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 35
# Number of test batches: 34

# %% [markdown]
# # parameters and augmentations

# %%
resize_and_rescale = keras.Sequential([
  keras.layers.Resizing(224, 224),
  keras.layers.Rescaling(1./127.5, offset=-1),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2)
])

# %%
no_of_classes = len(class_names)
no_of_classes
# Out:
# 4

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS=3

# %%
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

# %%
epochs = 150

# %% [markdown]
# # Loading base model

# %% [markdown]
# The weights in this model have been obtained by training on the ILSVRC-2012-CLS dataset for image classification ("Imagenet").

# %%
#Create the base model from the pre-trained model efficientnetB0
base_model = tf.keras.applications.VGG16(input_shape=input_shape,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
base_model.trainable = False

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

# %% [markdown]
# # model

# %%
def create_model():
  inputs = tf.keras.Input(shape=input_shape)
  x = resize_and_rescale(inputs)
  x = data_augmentation(x)
  x = base_model(x, training=False)
  x = global_average_layer(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  outputs = layers.Dense(no_of_classes, activation='softmax')(x)
  model = tf.keras.Model(inputs, outputs)
  model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  model.summary()
  return model

# %% [markdown]
# ## Early stopping

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
                                                    monitor='val_loss',
                                                    mode='min',
                                                    patience=5,
                                                    restore_best_weights=True
                                                    )

# %% [markdown]
# # Training, Save and evaluation functions

# %%
model_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Final_v1/CNN_model_selecting/VGG16/models'

# %%
model = create_model()
history = model.fit(
                    train_ds,
                    batch_size=BATCH_SIZE,
                    validation_data=validation_dataset,
                    verbose=1,
                    epochs=epochs,
                    callbacks=[early_stopping]
                    )

model.save(os.path.join(model_path, f'VGG16_model.keras'))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 4)                 2052
#
# =================================================================
# Total params: 14716740 (56.14 MB)
# Trainable params: 2052 (8.02 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Epoch 1/150
# 161/161 [==============================] - 1897s 12s/step - loss: 1.0290 - accuracy: 0.6118 - val_loss: 0.6814 - val_accuracy: 0.8963
# Epoch 2/150
# 161/161 [==============================] - 31s 187ms/step - loss: 0.6198 - accuracy: 0.8442 - val_loss: 0.4674 - val_accuracy: 0.9197
# Epoch 3/150
# 161/161 [==============================] - 32s 193ms/step - loss: 0.4789 - accuracy: 0.8801 - val_loss: 0.3767 - val_accuracy: 0.9279
# Epoch 4/150
# 161/161 [==============================] - 32s 196ms/step - loss: 0.4029 - accuracy: 0.8945 - val_loss: 0.3234 - val_accuracy: 0.9324
# Epoch 5/150
# 161/161 [==============================] - 34s 207ms/step - loss: 0.3587 - accuracy: 0.9000 - val_loss: 0.2876 - val_accuracy: 0.9387
# Epoch 6/150
# 161/161 [==============================] - 32s 194ms/step - loss: 0.3255 - accuracy: 0.9021 - val_loss: 0.2638 - val_accuracy: 0.9432
# Epoch 7/150
# 161/161 [==============================] - 35s 212ms/step - loss: 0.3005 - accuracy: 0.9099 - val_loss: 0.2478 - val_accuracy: 0.9360
# Epoch 8/150
# 161/161 [==============================] - 34s 207ms/step - loss: 0.2863 - accuracy: 0.9152 - val_loss: 0.2354 - val_accuracy: 0.9351
# Epoch 9/150
# 161/161 [==============================] - 35s 211ms/step - loss: 0.2665 - accuracy: 0.9212 - val_loss: 0.2232 - val_accuracy: 0.9378
# Epoch 10/150
# 161/161 [==============================] - 34s 203ms/step - loss: 0.2544 - accuracy: 0.9210 - val_loss: 0.2106 - val_accuracy: 0.9423
# Epoch 11/150
# 161/161 [==============================] - 35s 214ms/step - loss: 0.2486 - accuracy: 0.9210 - val_loss: 0.1989 - val_accuracy: 0.9441
# Epoch 12/150
# 161/161 [==============================] - 33s 202ms/step - loss: 0.2322 - accuracy: 0.9273 - val_loss: 0.1925 - val_accuracy: 0.9459
# Epoch 13/150
# 161/161 [==============================] - 33s 201ms/step - loss: 0.2292 - accuracy: 0.9306 - val_loss: 0.1857 - val_accuracy: 0.9468
# Epoch 14/150
# 161/161 [==============================] - 33s 198ms/step - loss: 0.2200 - accuracy: 0.9323 - val_loss: 0.1806 - val_accuracy: 0.9432
# Epoch 15/150
# 161/161 [==============================] - 34s 204ms/step - loss: 0.2071 - accuracy: 0.9349 - val_loss: 0.1787 - val_accuracy: 0.9477
# Epoch 16/150
# 161/161 [==============================] - 33s 200ms/step - loss: 0.2125 - accuracy: 0.9323 - val_loss: 0.1715 - val_accuracy: 0.9486
# Epoch 17/150
# 161/161 [==============================] - 35s 210ms/step - loss: 0.2031 - accuracy: 0.9316 - val_loss: 0.1693 - val_accuracy: 0.9468
# Epoch 18/150
# 161/161 [==============================] - 33s 201ms/step - loss: 0.1938 - accuracy: 0.9370 - val_loss: 0.1667 - val_accuracy: 0.9441
# Epoch 19/150
# 161/161 [==============================] - 35s 213ms/step - loss: 0.2000 - accuracy: 0.9339 - val_loss: 0.1627 - val_accuracy: 0.9486
# Epoch 20/150
# 161/161 [==============================] - 33s 198ms/step - loss: 0.1907 - accuracy: 0.9351 - val_loss: 0.1634 - val_accuracy: 0.9477
# Epoch 21/150
# 161/161 [==============================] - 32s 196ms/step - loss: 0.1845 - accuracy: 0.9364 - val_loss: 0.1551 - val_accuracy: 0.9495
# Epoch 22/150
# 161/161 [==============================] - 33s 202ms/step - loss: 0.1818 - accuracy: 0.9399 - val_loss: 0.1549 - val_accuracy: 0.9486
# Epoch 23/150
# 161/161 [==============================] - 33s 200ms/step - loss: 0.1843 - accuracy: 0.9409 - val_loss: 0.1501 - val_accuracy: 0.9477
# Epoch 24/150
# 161/161 [==============================] - 35s 211ms/step - loss: 0.1743 - accuracy: 0.9394 - val_loss: 0.1508 - val_accuracy: 0.9486
# Epoch 25/150
# 161/161 [==============================] - 33s 200ms/step - loss: 0.1697 - accuracy: 0.9392 - val_loss: 0.1511 - val_accuracy: 0.9522
# Epoch 26/150
# 161/161 [==============================] - 32s 194ms/step - loss: 0.1788 - accuracy: 0.9407 - val_loss: 0.1534 - val_accuracy: 0.9522
# Epoch 27/150
# 161/161 [==============================] - 33s 198ms/step - loss: 0.1685 - accuracy: 0.9425 - val_loss: 0.1408 - val_accuracy: 0.9522
# Epoch 28/150
# 161/161 [==============================] - 35s 210ms/step - loss: 0.1754 - accuracy: 0.9370 - val_loss: 0.1414 - val_accuracy: 0.9549
# Epoch 29/150
# 161/161 [==============================] - 35s 210ms/step - loss: 0.1676 - accuracy: 0.9398 - val_loss: 0.1412 - val_accuracy: 0.9495
# Epoch 30/150
# 161/161 [==============================] - 32s 196ms/step - loss: 0.1651 - accuracy: 0.9444 - val_loss: 0.1407 - val_accuracy: 0.9504
# Epoch 31/150
# 161/161 [==============================] - 35s 211ms/step - loss: 0.1671 - accuracy: 0.9409 - val_loss: 0.1410 - val_accuracy: 0.9513
# Epoch 32/150
# 161/161 [==============================] - 33s 201ms/step - loss: 0.1592 - accuracy: 0.9425 - val_loss: 0.1375 - val_accuracy: 0.9504
# Epoch 33/150
# 161/161 [==============================] - 33s 199ms/step - loss: 0.1632 - accuracy: 0.9468 - val_loss: 0.1376 - val_accuracy: 0.9495
# Epoch 34/150
# 161/161 [==============================] - 35s 215ms/step - loss: 0.1627 - accuracy: 0.9419 - val_loss: 0.1366 - val_accuracy: 0.9513
# Epoch 35/150
# 161/161 [==============================] - 33s 200ms/step - loss: 0.1579 - accuracy: 0.9440 - val_loss: 0.1323 - val_accuracy: 0.9549
# Epoch 36/150
# 161/161 [==============================] - 36s 215ms/step - loss: 0.1558 - accuracy: 0.9440 - val_loss: 0.1348 - val_accuracy: 0.9513
# Epoch 37/150
# 161/161 [==============================] - 35s 213ms/step - loss: 0.1564 - accuracy: 0.9450 - val_loss: 0.1325 - val_accuracy: 0.9549
# Epoch 38/150
# 161/161 [==============================] - 35s 215ms/step - loss: 0.1617 - accuracy: 0.9429 - val_loss: 0.1307 - val_accuracy: 0.9504
# Epoch 39/150
# 161/161 [==============================] - 33s 202ms/step - loss: 0.1560 - accuracy: 0.9454 - val_loss: 0.1286 - val_accuracy: 0.9549
# Epoch 40/150
# 161/161 [==============================] - 35s 215ms/step - loss: 0.1544 - accuracy: 0.9415 - val_loss: 0.1287 - val_accuracy: 0.9531
# Epoch 41/150
# 161/161 [==============================] - 33s 199ms/step - loss: 0.1491 - accuracy: 0.9483 - val_loss: 0.1272 - val_accuracy: 0.9549
# Epoch 42/150
# 161/161 [==============================] - 33s 197ms/step - loss: 0.1560 - accuracy: 0.9466 - val_loss: 0.1316 - val_accuracy: 0.9549
# Epoch 43/150
# 161/161 [==============================] - 34s 205ms/step - loss: 0.1557 - accuracy: 0.9419 - val_loss: 0.1298 - val_accuracy: 0.9522
# Epoch 44/150
# 161/161 [==============================] - 33s 202ms/step - loss: 0.1498 - accuracy: 0.9479 - val_loss: 0.1278 - val_accuracy: 0.9549
# Epoch 45/150
# 161/161 [==============================] - 34s 205ms/step - loss: 0.1531 - accuracy: 0.9452 - val_loss: 0.1278 - val_accuracy: 0.9540
# Epoch 46/150
# 161/161 [==============================] - 34s 207ms/step - loss: 0.1543 - accuracy: 0.9407 - val_loss: 0.1275 - val_accuracy: 0.9558

# %%
test_loss, test_acc = model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 5s 141ms/step - loss: 0.1317 - accuracy: 0.9476

# %%
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# Test accuracy: 0.9476103186607361
# Test loss: 0.13174206018447876

# %% [markdown]
# # loading model(if needed)

# %%
#model = create_model()

# %%
model = tf.keras.models.load_model(os.path.join(model_path, f'VGG16_model.keras'))

# %% [markdown]
# # predictions

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 703s 20s/step - loss: 0.1317 - accuracy: 0.9476
# [0.13174207508563995, 0.9476103186607361]

# %%
predictions = model.predict(test_dataset)
# Out:
# 34/34 [==============================] - 706s 21s/step

# %%
predictions
# Out:
# array([[7.8449726e-01, 1.8850390e-03, 2.9791705e-04, 2.1331970e-01],
#        [6.5029337e-05, 9.9905604e-01, 1.4643221e-09, 8.7897602e-04],
#        [5.8195069e-02, 6.9534016e-04, 1.5918109e-06, 9.4110799e-01],
#        ...,
#        [1.7400545e-03, 1.4653656e-04, 9.9290901e-01, 5.2043092e-03],
#        [1.7554265e-02, 3.7400164e-03, 4.1490767e-07, 9.7870529e-01],
#        [2.7173378e-02, 9.6113479e-01, 1.7633729e-07, 1.1691628e-02]],
#       dtype=float32)

# %%
y_pred_classes = np.argmax(predictions, axis=1)
y_pred_classes
# Out:
# array([0, 1, 3, ..., 2, 3, 1])

# %%
y_true = np.concatenate([y for x, y in test_dataset], axis=0)
y_true
# Out:
# array([0, 1, 3, ..., 2, 3, 1], dtype=int32)

# %%
import collections
counter = collections.Counter(y_true)
print(counter)
# Out:
# Counter({3: 297, 1: 295, 2: 269, 0: 227})

# %%
cm = confusion_matrix(y_true, y_pred_classes)

# Create a larger figure
fig, ax = plt.subplots(figsize=(10, 10))

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, ax=ax)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
#                       precision    recall  f1-score   support
#
# Cercospora Leaf Spot       0.89      0.87      0.88       227
#          Common Rust       1.00      1.00      1.00       295
#              Healthy       0.99      1.00      0.99       269
# Northern Leaf Blight       0.90      0.91      0.91       297
#
#             accuracy                           0.95      1088
#            macro avg       0.94      0.94      0.94      1088
#         weighted avg       0.95      0.95      0.95      1088

# %% [markdown]
# # show incorrectly classified images

# %%
# Find incorrectly classified images
incorrect_indices = np.where(y_pred_classes != y_true)[0]
incorrect_indices
# Out:
# array([  12,   25,   37,   61,   62,  171,  172,  177,  190,  209,  210,
#         218,  256,  262,  288,  293,  306,  310,  338,  382,  394,  399,
#         417,  485,  489,  495,  501,  545,  607,  616,  619,  623,  631,
#         657,  660,  689,  707,  725,  731,  742,  744,  779,  783,  809,
#         819,  841,  878,  884,  891,  900,  918,  933,  943,  972,  982,
#        1003, 1011])

# %%
# Get the images and labels
images = np.concatenate([x for x, y in test_dataset], axis=0)
incorrect_images = images[incorrect_indices]
incorrect_true_labels = y_true[incorrect_indices]
incorrect_pred_labels = y_pred_classes[incorrect_indices]

# %%
# Display incorrectly classified images
num_images_to_display = 10  # Number of images to display
plt.figure(figsize=(15, 15))
for i in range(min(num_images_to_display, len(incorrect_images))):
    plt.subplot(5, 2, i + 1)
    plt.imshow(incorrect_images[i].astype("uint8"))
    plt.title(f"True: {class_names[incorrect_true_labels[i]]}, Pred: {class_names[incorrect_pred_labels[i]]}")
    plt.axis("off")
plt.show()

# %% [markdown]
# leaf spot : Mature lesions from gray leaf spot are rectangular, as they are restricted by the leaf veins.
#
# leaf blight : Northern corn leaf blight is easily identified by the 1- to 6-inch cigar-shaped lesions on lower leaves, which may be grayish-green to tan in color.

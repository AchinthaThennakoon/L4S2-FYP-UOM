# %% [markdown]
# <a href="https://colab.research.google.com/github/AchinthaThennakoon/L4S2-FYP-UOM/blob/main/Final_v1/CNN_model_selecting/Restnet/Restnet_v2(all_diseases).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# %%
import pandas as pd

# %%
import pickle

# %%
import json
import os

# %%
import numpy as np

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
import tensorflow_hub as hub

# %% [markdown]
# # loading data set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train'

# %%
data_dir = pathlib.Path(dataset_path)
data_dir
# Out:
# PosixPath('/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train')

# %%
train_ds,val_ds =  keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.3,
    subset="both",
    seed=123,
    shuffle=True,
    batch_size=32,
    image_size=(224, 224),
    )
# Out:
# Found 7326 files belonging to 4 classes.
# Using 5129 files for training.
# Using 2197 files for validation.

# %%
for batch in train_ds.take(1):
    images, labels = batch
    print(images.shape)  # Should be (32, 224, 224, 3) if batch size is 32
    print(labels.shape)
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['Cercospora Leaf Spot', 'Common Rust', 'Healthy', 'Northern Leaf Blight']

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in train_ds.take(1):
    for i in range(8):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ## divide validation set to test & validation

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(val_ds))
# Out:
# Number of validation batches: 69

# %%
val_batches = tf.data.experimental.cardinality(val_ds)
test_dataset = val_ds.take(val_batches // 2)
validation_dataset = val_ds.skip(val_batches // 2)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 35
# Number of test batches: 34

# %% [markdown]
# # parameters and augmentations

# %%
resize_and_rescale = keras.Sequential([
  keras.layers.Resizing(224, 224),
  keras.layers.Rescaling(1./127.5, offset=-1),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2)
])

# %%
no_of_classes = len(class_names)
no_of_classes
# Out:
# 4

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS=3

# %%
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

# %%
epochs = 150

# %% [markdown]
# # Loading base model

# %%
feature_extractor_model='https://www.kaggle.com/models/tensorflow/resnet-50/TensorFlow2/feature-vector/1'

# %%
feature_extractor_layer = hub.KerasLayer(
    feature_extractor_model,
    input_shape=(224, 224, 3),
    trainable=False)

# %% [markdown]
# The weights in this model have been obtained by training on the ILSVRC-2012-CLS dataset for image classification ("Imagenet").

# %%
# Create the base model from the pre-trained model MobileNet V2
# base_model = tf.keras.applications.MobileNetV2(input_shape=input_shape,
#                                                include_top=False,
#                                                weights='imagenet')

# %%
feature_extractor_layer.trainable = False

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

# %% [markdown]
# # model

# %%
def create_model():
  inputs = tf.keras.Input(shape=input_shape)
  x = resize_and_rescale(inputs)
  x = data_augmentation(x)
  x = feature_extractor_layer(x, training=False)
  # x = global_average_layer(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  outputs = layers.Dense(no_of_classes, activation='softmax')(x)
  model = tf.keras.Model(inputs, outputs)
  model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  model.summary()
  return model

# %% [markdown]
# ## Early stopping

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
                                                    monitor='val_loss',
                                                    mode='min',
                                                    patience=5,
                                                    restore_best_weights=True
                                                    )

# %% [markdown]
# # Training, Save and evaluation functions

# %%
model_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Final_v1/CNN_model_selecting/Restnet/models'

# %%
model = create_model()
history = model.fit(
                    train_ds,
                    batch_size=BATCH_SIZE,
                    validation_data=validation_dataset,
                    verbose=1,
                    epochs=epochs,
                    callbacks=[early_stopping]
                    )

model.save(os.path.join(model_path, f'resnet50_model.keras'))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  keras_layer (KerasLayer)    (None, 2048)              23561152
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 4)                 8196
#
# =================================================================
# Total params: 23569348 (89.91 MB)
# Trainable params: 8196 (32.02 KB)
# Non-trainable params: 23561152 (89.88 MB)
# _________________________________________________________________
# Epoch 1/150
# 161/161 [==============================] - 2008s 12s/step - loss: 0.5214 - accuracy: 0.7937 - val_loss: 0.2208 - val_accuracy: 0.9116
# Epoch 2/150
# 161/161 [==============================] - 31s 188ms/step - loss: 0.2684 - accuracy: 0.8895 - val_loss: 0.1537 - val_accuracy: 0.9378
# Epoch 3/150
# 161/161 [==============================] - 32s 197ms/step - loss: 0.2157 - accuracy: 0.9093 - val_loss: 0.1662 - val_accuracy: 0.9360
# Epoch 4/150
# 161/161 [==============================] - 35s 210ms/step - loss: 0.2026 - accuracy: 0.9203 - val_loss: 0.1566 - val_accuracy: 0.9369
# Epoch 5/150
# 161/161 [==============================] - 36s 216ms/step - loss: 0.1803 - accuracy: 0.9271 - val_loss: 0.1248 - val_accuracy: 0.9504
# Epoch 6/150
# 161/161 [==============================] - 33s 198ms/step - loss: 0.1644 - accuracy: 0.9360 - val_loss: 0.1059 - val_accuracy: 0.9612
# Epoch 7/150
# 161/161 [==============================] - 30s 184ms/step - loss: 0.1595 - accuracy: 0.9370 - val_loss: 0.1159 - val_accuracy: 0.9612
# Epoch 8/150
# 161/161 [==============================] - 30s 178ms/step - loss: 0.1493 - accuracy: 0.9413 - val_loss: 0.1087 - val_accuracy: 0.9630
# Epoch 9/150
# 161/161 [==============================] - 31s 188ms/step - loss: 0.1535 - accuracy: 0.9380 - val_loss: 0.1052 - val_accuracy: 0.9639
# Epoch 10/150
# 161/161 [==============================] - 31s 186ms/step - loss: 0.1476 - accuracy: 0.9380 - val_loss: 0.0935 - val_accuracy: 0.9684
# Epoch 11/150
# 161/161 [==============================] - 33s 196ms/step - loss: 0.1391 - accuracy: 0.9433 - val_loss: 0.1023 - val_accuracy: 0.9630
# Epoch 12/150
# 161/161 [==============================] - 30s 179ms/step - loss: 0.1364 - accuracy: 0.9460 - val_loss: 0.0954 - val_accuracy: 0.9693
# Epoch 13/150
# 161/161 [==============================] - 30s 180ms/step - loss: 0.1273 - accuracy: 0.9483 - val_loss: 0.0891 - val_accuracy: 0.9693
# Epoch 14/150
# 161/161 [==============================] - 31s 187ms/step - loss: 0.1302 - accuracy: 0.9495 - val_loss: 0.0786 - val_accuracy: 0.9766
# Epoch 15/150
# 161/161 [==============================] - 32s 192ms/step - loss: 0.1300 - accuracy: 0.9472 - val_loss: 0.0884 - val_accuracy: 0.9693
# Epoch 16/150
# 161/161 [==============================] - 31s 187ms/step - loss: 0.1344 - accuracy: 0.9454 - val_loss: 0.1018 - val_accuracy: 0.9612
# Epoch 17/150
# 161/161 [==============================] - 30s 179ms/step - loss: 0.1303 - accuracy: 0.9450 - val_loss: 0.1209 - val_accuracy: 0.9423
# Epoch 18/150
# 161/161 [==============================] - 35s 209ms/step - loss: 0.1341 - accuracy: 0.9466 - val_loss: 0.0706 - val_accuracy: 0.9802
# Epoch 19/150
# 161/161 [==============================] - 31s 189ms/step - loss: 0.1259 - accuracy: 0.9507 - val_loss: 0.1049 - val_accuracy: 0.9549
# Epoch 20/150
# 161/161 [==============================] - 29s 175ms/step - loss: 0.1384 - accuracy: 0.9423 - val_loss: 0.0729 - val_accuracy: 0.9739
# Epoch 21/150
# 161/161 [==============================] - 29s 174ms/step - loss: 0.1215 - accuracy: 0.9501 - val_loss: 0.0753 - val_accuracy: 0.9748
# Epoch 22/150
# 161/161 [==============================] - 31s 188ms/step - loss: 0.1251 - accuracy: 0.9503 - val_loss: 0.0729 - val_accuracy: 0.9793
# Epoch 23/150
# 161/161 [==============================] - 33s 199ms/step - loss: 0.1303 - accuracy: 0.9468 - val_loss: 0.0901 - val_accuracy: 0.9657

# %%
test_loss, test_acc = model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 6s 148ms/step - loss: 0.0957 - accuracy: 0.9586

# %%
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# Test accuracy: 0.9586396813392639
# Test loss: 0.09566117823123932

# %% [markdown]
# # loading model(if needed)

# %%
#model = create_model()

# %%
#model = tf.keras.models.load_model(os.path.join(model_path, f'mobilenet_v2_model.keras.keras'))

# %% [markdown]
# # predictions

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 5s 151ms/step - loss: 0.0957 - accuracy: 0.9586
# [0.09566117823123932, 0.9586396813392639]

# %%
predictions = model.predict(test_dataset)
# Out:
# 34/34 [==============================] - 5s 125ms/step

# %%
predictions
# Out:
# array([[9.9215454e-01, 1.0160551e-07, 7.6232762e-09, 7.8453096e-03],
#        [8.0343803e-09, 1.0000000e+00, 1.4114565e-14, 2.7409333e-12],
#        [9.9433124e-02, 1.5928202e-06, 9.5094492e-07, 9.0056431e-01],
#        ...,
#        [6.2056587e-09, 2.8677765e-12, 1.0000000e+00, 1.4508758e-08],
#        [4.1875811e-04, 1.3329780e-07, 1.6394828e-09, 9.9958116e-01],
#        [1.5477807e-09, 1.0000000e+00, 8.6073381e-14, 2.1536473e-14]],
#       dtype=float32)

# %%
y_pred_classes = np.argmax(predictions, axis=1)
y_pred_classes
# Out:
# array([0, 1, 3, ..., 2, 3, 1])

# %%
y_true = np.concatenate([y for x, y in test_dataset], axis=0)
y_true
# Out:
# array([0, 1, 3, ..., 2, 3, 1], dtype=int32)

# %%
import collections
counter = collections.Counter(y_true)
print(counter)
# Out:
# Counter({3: 297, 1: 295, 2: 269, 0: 227})

# %%
cm = confusion_matrix(y_true, y_pred_classes)

# Create a larger figure
fig, ax = plt.subplots(figsize=(10, 10))

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, ax=ax)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
#                       precision    recall  f1-score   support
#
# Cercospora Leaf Spot       0.91      0.91      0.91       227
#          Common Rust       0.99      1.00      0.99       295
#              Healthy       0.99      1.00      0.99       269
# Northern Leaf Blight       0.94      0.92      0.93       297
#
#             accuracy                           0.96      1088
#            macro avg       0.96      0.96      0.96      1088
#         weighted avg       0.96      0.96      0.96      1088

# %% [markdown]
# # show incorrectly classified images

# %%
# Find incorrectly classified images
incorrect_indices = np.where(y_pred_classes != y_true)[0]
incorrect_indices
# Out:
# array([  14,   44,   98,  139,  148,  154,  171,  172,  188,  195,  201,
#         234,  256,  285,  306,  394,  399,  408,  424,  426,  448,  451,
#         480,  485,  489,  590,  616,  619,  623,  660,  698,  731,  742,
#         744,  783,  819,  833,  841,  872,  878,  884,  938,  940,  943,
#        1065])

# %%
# Get the images and labels
images = np.concatenate([x for x, y in test_dataset], axis=0)
incorrect_images = images[incorrect_indices]
incorrect_true_labels = y_true[incorrect_indices]
incorrect_pred_labels = y_pred_classes[incorrect_indices]

# %%
# Display incorrectly classified images
num_images_to_display = 10  # Number of images to display
plt.figure(figsize=(15, 15))
for i in range(min(num_images_to_display, len(incorrect_images))):
    plt.subplot(5, 2, i + 1)
    plt.imshow(incorrect_images[i].astype("uint8"))
    plt.title(f"True: {class_names[incorrect_true_labels[i]]}, Pred: {class_names[incorrect_pred_labels[i]]}")
    plt.axis("off")
plt.show()

# %% [markdown]
# leaf spot : Mature lesions from gray leaf spot are rectangular, as they are restricted by the leaf veins.
#
# leaf blight : Northern corn leaf blight is easily identified by the 1- to 6-inch cigar-shaped lesions on lower leaves, which may be grayish-green to tan in color.

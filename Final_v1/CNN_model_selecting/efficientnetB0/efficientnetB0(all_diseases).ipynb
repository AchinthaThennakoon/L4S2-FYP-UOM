# %% [markdown]
# <a href="https://colab.research.google.com/github/AchinthaThennakoon/L4S2-FYP-UOM/blob/main/Final_v1/CNN_model_selecting/efficientnetB0/efficientnetB0(all_diseases).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# %%
import pandas as pd

# %%
import pickle

# %%
import json
import os

# %%
import numpy as np

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
import tensorflow_hub as hub

# %% [markdown]
# # loading data set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train'

# %%
data_dir = pathlib.Path(dataset_path)
data_dir
# Out:
# PosixPath('/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train')

# %%
train_ds,val_ds =  keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.3,
    subset="both",
    seed=123,
    shuffle=True,
    batch_size=32,
    image_size=(224, 224),
    )
# Out:
# Found 7326 files belonging to 4 classes.
# Using 5129 files for training.
# Using 2197 files for validation.

# %%
for batch in train_ds.take(1):
    images, labels = batch
    print(images.shape)  # Should be (32, 224, 224, 3) if batch size is 32
    print(labels.shape)
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['Cercospora Leaf Spot', 'Common Rust', 'Healthy', 'Northern Leaf Blight']

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in train_ds.take(1):
    for i in range(8):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ## divide validation set to test & validation

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(val_ds))
# Out:
# Number of validation batches: 69

# %%
val_batches = tf.data.experimental.cardinality(val_ds)
test_dataset = val_ds.take(val_batches // 2)
validation_dataset = val_ds.skip(val_batches // 2)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 35
# Number of test batches: 34

# %% [markdown]
# # parameters and augmentations

# %%
resize_and_rescale = keras.Sequential([
  keras.layers.Resizing(224, 224),
  keras.layers.Rescaling(1./127.5, offset=-1),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2)
])

# %%
no_of_classes = len(class_names)
no_of_classes
# Out:
# 4

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS=3

# %%
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

# %%
epochs = 150

# %% [markdown]
# # Loading base model

# %% [markdown]
# The weights in this model have been obtained by training on the ILSVRC-2012-CLS dataset for image classification ("Imagenet").

# %%
#Create the base model from the pre-trained model efficientnetB0
base_model = tf.keras.applications.EfficientNetB0(input_shape=input_shape,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step

# %%
base_model.trainable = False

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

# %% [markdown]
# # model

# %%
def create_model():
  inputs = tf.keras.Input(shape=input_shape)
  x = resize_and_rescale(inputs)
  x = data_augmentation(x)
  x = base_model(x, training=False)
  x = global_average_layer(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  outputs = layers.Dense(no_of_classes, activation='softmax')(x)
  model = tf.keras.Model(inputs, outputs)
  model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  model.summary()
  return model

# %% [markdown]
# ## Early stopping

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
                                                    monitor='val_loss',
                                                    mode='min',
                                                    patience=5,
                                                    restore_best_weights=True
                                                    )

# %% [markdown]
# # Training, Save and evaluation functions

# %%
model_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Final_v1/CNN_model_selecting/efficientnetB0/models'

# %%
model = create_model()
history = model.fit(
                    train_ds,
                    batch_size=BATCH_SIZE,
                    validation_data=validation_dataset,
                    verbose=1,
                    epochs=epochs,
                    callbacks=[early_stopping]
                    )

model.save(os.path.join(model_path, f'efficientnetB0_model.keras'))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
#
#  efficientnetb0 (Functional  (None, 7, 7, 1280)        4049571
#  )
#
#  global_average_pooling2d_1  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 4)                 5124
#
# =================================================================
# Total params: 4054695 (15.47 MB)
# Trainable params: 5124 (20.02 KB)
# Non-trainable params: 4049571 (15.45 MB)
# _________________________________________________________________
# Epoch 1/150
# 161/161 [==============================] - 2006s 12s/step - loss: 1.4054 - accuracy: 0.2579 - val_loss: 1.4155 - val_accuracy: 0.2597
# Epoch 2/150
# 161/161 [==============================] - 28s 168ms/step - loss: 1.3947 - accuracy: 0.2630 - val_loss: 1.3844 - val_accuracy: 0.2489
# Epoch 3/150
# 161/161 [==============================] - 28s 170ms/step - loss: 1.3901 - accuracy: 0.2780 - val_loss: 1.3667 - val_accuracy: 0.3877
# Epoch 4/150
# 161/161 [==============================] - 29s 176ms/step - loss: 1.3836 - accuracy: 0.2808 - val_loss: 1.3647 - val_accuracy: 0.2579
# Epoch 5/150
# 161/161 [==============================] - 29s 174ms/step - loss: 1.3736 - accuracy: 0.3049 - val_loss: 1.3571 - val_accuracy: 0.2660
# Epoch 6/150
# 161/161 [==============================] - 28s 167ms/step - loss: 1.3706 - accuracy: 0.3010 - val_loss: 1.3540 - val_accuracy: 0.3318
# Epoch 7/150
# 161/161 [==============================] - 28s 168ms/step - loss: 1.3659 - accuracy: 0.3081 - val_loss: 1.3497 - val_accuracy: 0.2561
# Epoch 8/150
# 161/161 [==============================] - 28s 167ms/step - loss: 1.3579 - accuracy: 0.3192 - val_loss: 1.3368 - val_accuracy: 0.3724
# Epoch 9/150
# 161/161 [==============================] - 29s 177ms/step - loss: 1.3579 - accuracy: 0.3268 - val_loss: 1.3393 - val_accuracy: 0.2822
# Epoch 10/150
# 161/161 [==============================] - 28s 172ms/step - loss: 1.3516 - accuracy: 0.3387 - val_loss: 1.3395 - val_accuracy: 0.3147
# Epoch 11/150
# 161/161 [==============================] - 28s 169ms/step - loss: 1.3485 - accuracy: 0.3264 - val_loss: 1.3282 - val_accuracy: 0.3291
# Epoch 12/150
# 161/161 [==============================] - 30s 179ms/step - loss: 1.3470 - accuracy: 0.3472 - val_loss: 1.3504 - val_accuracy: 0.2894
# Epoch 13/150
# 161/161 [==============================] - 29s 175ms/step - loss: 1.3450 - accuracy: 0.3428 - val_loss: 1.3257 - val_accuracy: 0.2714
# Epoch 14/150
# 161/161 [==============================] - 29s 171ms/step - loss: 1.3369 - accuracy: 0.3484 - val_loss: 1.3222 - val_accuracy: 0.2904
# Epoch 15/150
# 161/161 [==============================] - 32s 192ms/step - loss: 1.3349 - accuracy: 0.3523 - val_loss: 1.3042 - val_accuracy: 0.5086
# Epoch 16/150
# 161/161 [==============================] - 31s 187ms/step - loss: 1.3267 - accuracy: 0.3640 - val_loss: 1.3070 - val_accuracy: 0.3156
# Epoch 17/150
# 161/161 [==============================] - 28s 167ms/step - loss: 1.3327 - accuracy: 0.3509 - val_loss: 1.2951 - val_accuracy: 0.5068
# Epoch 18/150
# 161/161 [==============================] - 27s 166ms/step - loss: 1.3201 - accuracy: 0.3589 - val_loss: 1.3025 - val_accuracy: 0.3499
# Epoch 19/150
# 161/161 [==============================] - 28s 170ms/step - loss: 1.3139 - accuracy: 0.3819 - val_loss: 1.2891 - val_accuracy: 0.5113
# Epoch 20/150
# 161/161 [==============================] - 29s 173ms/step - loss: 1.3083 - accuracy: 0.3907 - val_loss: 1.2885 - val_accuracy: 0.4932
# Epoch 21/150
# 161/161 [==============================] - 29s 175ms/step - loss: 1.3105 - accuracy: 0.3827 - val_loss: 1.2846 - val_accuracy: 0.5149
# Epoch 22/150
# 161/161 [==============================] - 29s 178ms/step - loss: 1.3086 - accuracy: 0.3812 - val_loss: 1.2759 - val_accuracy: 0.5095
# Epoch 23/150
# 161/161 [==============================] - 29s 172ms/step - loss: 1.3012 - accuracy: 0.3903 - val_loss: 1.3022 - val_accuracy: 0.2858
# Epoch 24/150
# 161/161 [==============================] - 28s 171ms/step - loss: 1.2988 - accuracy: 0.3909 - val_loss: 1.2873 - val_accuracy: 0.4391
# Epoch 25/150
# 161/161 [==============================] - 28s 170ms/step - loss: 1.2953 - accuracy: 0.4012 - val_loss: 1.2940 - val_accuracy: 0.4013
# Epoch 26/150
# 161/161 [==============================] - 28s 169ms/step - loss: 1.2992 - accuracy: 0.3880 - val_loss: 1.2636 - val_accuracy: 0.5005
# Epoch 27/150
# 161/161 [==============================] - 28s 172ms/step - loss: 1.2950 - accuracy: 0.3944 - val_loss: 1.2758 - val_accuracy: 0.3652
# Epoch 28/150
# 161/161 [==============================] - 28s 172ms/step - loss: 1.2898 - accuracy: 0.3895 - val_loss: 1.2533 - val_accuracy: 0.6267
# Epoch 29/150
# 161/161 [==============================] - 28s 171ms/step - loss: 1.2878 - accuracy: 0.4018 - val_loss: 1.2575 - val_accuracy: 0.5239
# Epoch 30/150
# 161/161 [==============================] - 29s 177ms/step - loss: 1.2869 - accuracy: 0.3940 - val_loss: 1.2533 - val_accuracy: 0.5302
# Epoch 31/150
# 161/161 [==============================] - 29s 175ms/step - loss: 1.2862 - accuracy: 0.3940 - val_loss: 1.2484 - val_accuracy: 0.5194
# Epoch 32/150
# 161/161 [==============================] - 32s 193ms/step - loss: 1.2791 - accuracy: 0.4118 - val_loss: 1.2591 - val_accuracy: 0.3706
# Epoch 33/150
# 161/161 [==============================] - 32s 194ms/step - loss: 1.2773 - accuracy: 0.4014 - val_loss: 1.2564 - val_accuracy: 0.4869
# Epoch 34/150
# 161/161 [==============================] - 29s 176ms/step - loss: 1.2781 - accuracy: 0.4092 - val_loss: 1.2437 - val_accuracy: 0.4491
# Epoch 35/150
# 161/161 [==============================] - 29s 173ms/step - loss: 1.2722 - accuracy: 0.4268 - val_loss: 1.2300 - val_accuracy: 0.6357
# Epoch 36/150
# 161/161 [==============================] - 29s 176ms/step - loss: 1.2722 - accuracy: 0.4046 - val_loss: 1.2310 - val_accuracy: 0.6249
# Epoch 37/150
# 161/161 [==============================] - 28s 170ms/step - loss: 1.2675 - accuracy: 0.4225 - val_loss: 1.2369 - val_accuracy: 0.5870
# Epoch 38/150
# 161/161 [==============================] - 28s 167ms/step - loss: 1.2681 - accuracy: 0.4149 - val_loss: 1.2389 - val_accuracy: 0.3950
# Epoch 39/150
# 161/161 [==============================] - 29s 175ms/step - loss: 1.2666 - accuracy: 0.4268 - val_loss: 1.2283 - val_accuracy: 0.5203
# Epoch 40/150
# 161/161 [==============================] - 29s 173ms/step - loss: 1.2671 - accuracy: 0.4104 - val_loss: 1.2347 - val_accuracy: 0.4779
# Epoch 41/150
# 161/161 [==============================] - 29s 173ms/step - loss: 1.2593 - accuracy: 0.4151 - val_loss: 1.2272 - val_accuracy: 0.4869
# Epoch 42/150
# 161/161 [==============================] - 30s 179ms/step - loss: 1.2575 - accuracy: 0.4165 - val_loss: 1.2361 - val_accuracy: 0.4031
# Epoch 43/150
# 161/161 [==============================] - 29s 173ms/step - loss: 1.2585 - accuracy: 0.4204 - val_loss: 1.2122 - val_accuracy: 0.5627
# Epoch 44/150
# 161/161 [==============================] - 29s 173ms/step - loss: 1.2601 - accuracy: 0.4163 - val_loss: 1.2189 - val_accuracy: 0.5365
# Epoch 45/150
# 161/161 [==============================] - 29s 176ms/step - loss: 1.2510 - accuracy: 0.4365 - val_loss: 1.2138 - val_accuracy: 0.5906
# Epoch 46/150
# 161/161 [==============================] - 34s 206ms/step - loss: 1.2513 - accuracy: 0.4299 - val_loss: 1.2279 - val_accuracy: 0.4238
# Epoch 47/150
# 161/161 [==============================] - 34s 203ms/step - loss: 1.2429 - accuracy: 0.4365 - val_loss: 1.2154 - val_accuracy: 0.4770
# Epoch 48/150
# 161/161 [==============================] - 30s 179ms/step - loss: 1.2469 - accuracy: 0.4305 - val_loss: 1.1967 - val_accuracy: 0.5753
# Epoch 49/150
# 161/161 [==============================] - 28s 172ms/step - loss: 1.2477 - accuracy: 0.4287 - val_loss: 1.2155 - val_accuracy: 0.4418
# Epoch 50/150
# 161/161 [==============================] - 29s 174ms/step - loss: 1.2432 - accuracy: 0.4336 - val_loss: 1.1923 - val_accuracy: 0.6447
# Epoch 51/150
# 161/161 [==============================] - 28s 171ms/step - loss: 1.2446 - accuracy: 0.4334 - val_loss: 1.1981 - val_accuracy: 0.5555
# Epoch 52/150
# 161/161 [==============================] - 29s 173ms/step - loss: 1.2351 - accuracy: 0.4471 - val_loss: 1.1924 - val_accuracy: 0.6592
# Epoch 53/150
# 161/161 [==============================] - 29s 177ms/step - loss: 1.2316 - accuracy: 0.4543 - val_loss: 1.1969 - val_accuracy: 0.4806
# Epoch 54/150
# 161/161 [==============================] - 28s 172ms/step - loss: 1.2360 - accuracy: 0.4434 - val_loss: 1.2043 - val_accuracy: 0.4463
# Epoch 55/150
# 161/161 [==============================] - 28s 169ms/step - loss: 1.2297 - accuracy: 0.4512 - val_loss: 1.1829 - val_accuracy: 0.5491
# Epoch 56/150
# 161/161 [==============================] - 28s 170ms/step - loss: 1.2371 - accuracy: 0.4404 - val_loss: 1.1992 - val_accuracy: 0.4301
# Epoch 57/150
# 161/161 [==============================] - 28s 172ms/step - loss: 1.2303 - accuracy: 0.4428 - val_loss: 1.2021 - val_accuracy: 0.3913
# Epoch 58/150
# 161/161 [==============================] - 29s 172ms/step - loss: 1.2274 - accuracy: 0.4516 - val_loss: 1.1863 - val_accuracy: 0.5969
# Epoch 59/150
# 161/161 [==============================] - 30s 179ms/step - loss: 1.2257 - accuracy: 0.4496 - val_loss: 1.1854 - val_accuracy: 0.5906
# Epoch 60/150
# 161/161 [==============================] - 33s 198ms/step - loss: 1.2302 - accuracy: 0.4360 - val_loss: 1.1833 - val_accuracy: 0.5041

# %%
test_loss, test_acc = model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 4s 115ms/step - loss: 1.1818 - accuracy: 0.5267

# %%
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# Test accuracy: 0.5266544222831726
# Test loss: 1.1817766427993774

# %% [markdown]
# # loading model(if needed)

# %%
#model = create_model()

# %%
#model = tf.keras.models.load_model(os.path.join(model_path, f'mobilenet_v2_model.keras.keras'))

# %% [markdown]
# # predictions

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 5s 157ms/step - loss: 1.1818 - accuracy: 0.5267
# [1.1817766427993774, 0.5266544222831726]

# %%
predictions = model.predict(test_dataset)
# Out:
# 34/34 [==============================] - 5s 116ms/step

# %%
predictions
# Out:
# array([[0.1721887 , 0.18550871, 0.35903782, 0.28326476],
#        [0.2600887 , 0.3971141 , 0.16455932, 0.1782379 ],
#        [0.20243429, 0.21846496, 0.30864128, 0.27045947],
#        ...,
#        [0.12173492, 0.15354447, 0.4564618 , 0.2682588 ],
#        [0.21707347, 0.22834265, 0.29333773, 0.26124614],
#        [0.27813295, 0.40647188, 0.14015704, 0.17523815]], dtype=float32)

# %%
y_pred_classes = np.argmax(predictions, axis=1)
y_pred_classes
# Out:
# array([2, 1, 2, ..., 2, 2, 1])

# %%
y_true = np.concatenate([y for x, y in test_dataset], axis=0)
y_true
# Out:
# array([0, 1, 3, ..., 2, 3, 1], dtype=int32)

# %%
import collections
counter = collections.Counter(y_true)
print(counter)
# Out:
# Counter({3: 297, 1: 295, 2: 269, 0: 227})

# %%
cm = confusion_matrix(y_true, y_pred_classes)

# Create a larger figure
fig, ax = plt.subplots(figsize=(10, 10))

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, ax=ax)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
#                       precision    recall  f1-score   support
#
# Cercospora Leaf Spot       0.64      0.19      0.30       227
#          Common Rust       0.68      0.93      0.78       295
#              Healthy       0.41      0.94      0.57       269
# Northern Leaf Blight       1.00      0.00      0.01       297
#
#             accuracy                           0.53      1088
#            macro avg       0.68      0.52      0.42      1088
#         weighted avg       0.69      0.53      0.42      1088

# %% [markdown]
# # show incorrectly classified images

# %%
# Find incorrectly classified images
incorrect_indices = np.where(y_pred_classes != y_true)[0]
incorrect_indices
# Out:
# array([   0,    2,    3,    4,    6,    7,   12,   13,   14,   15,   21,
#          25,   28,   34,   42,   44,   45,   46,   48,   49,   50,   53,
#          54,   57,   60,   61,   62,   64,   67,   68,   74,   75,   76,
#          77,   78,   79,   80,   83,   86,   89,   90,   92,   93,   94,
#          96,   98,  100,  102,  103,  106,  109,  113,  114,  116,  119,
#         121,  123,  124,  130,  131,  133,  136,  137,  138,  139,  140,
#         141,  143,  144,  148,  149,  151,  152,  154,  155,  157,  162,
#         165,  168,  170,  171,  172,  174,  177,  179,  181,  182,  184,
#         185,  187,  188,  190,  192,  193,  194,  195,  196,  200,  201,
#         202,  206,  209,  214,  215,  216,  217,  220,  222,  225,  226,
#         228,  229,  231,  232,  233,  234,  235,  236,  237,  241,  244,
#         246,  248,  249,  250,  252,  253,  255,  256,  257,  258,  262,
#         264,  265,  267,  270,  271,  272,  273,  275,  276,  277,  285,
#         287,  288,  289,  290,  291,  293,  294,  296,  297,  298,  299,
#         300,  301,  304,  306,  307,  310,  312,  319,  322,  323,  326,
#         327,  330,  338,  340,  343,  344,  345,  346,  347,  351,  354,
#         357,  358,  359,  360,  361,  362,  363,  365,  366,  367,  368,
#         369,  371,  375,  376,  378,  380,  382,  386,  389,  390,  392,
#         394,  396,  397,  398,  399,  401,  403,  408,  409,  414,  417,
#         419,  421,  424,  426,  428,  429,  430,  432,  436,  438,  441,
#         444,  448,  451,  452,  454,  455,  456,  457,  459,  461,  465,
#         468,  470,  471,  472,  473,  479,  480,  484,  485,  486,  489,
#         490,  492,  495,  497,  499,  500,  501,  503,  507,  512,  514,
#         515,  519,  520,  521,  523,  525,  526,  527,  528,  530,  531,
#         534,  535,  545,  549,  550,  551,  554,  555,  558,  560,  561,
#         565,  569,  571,  575,  580,  581,  584,  586,  590,  597,  600,
#         602,  604,  605,  606,  607,  611,  612,  613,  615,  616,  618,
#         620,  623,  627,  630,  631,  632,  634,  635,  640,  643,  644,
#         645,  646,  647,  651,  652,  656,  657,  658,  659,  660,  661,
#         662,  663,  664,  665,  666,  667,  668,  677,  678,  684,  686,
#         688,  691,  693,  694,  698,  699,  700,  702,  705,  706,  709,
#         712,  713,  714,  717,  720,  721,  723,  725,  727,  729,  731,
#         732,  733,  734,  735,  736,  737,  739,  740,  742,  743,  744,
#         746,  747,  748,  751,  760,  762,  764,  765,  767,  768,  769,
#         770,  772,  775,  778,  779,  780,  781,  782,  783,  789,  792,
#         794,  795,  796,  799,  800,  803,  804,  809,  811,  812,  813,
#         814,  816,  817,  819,  821,  822,  827,  828,  829,  830,  832,
#         833,  834,  835,  836,  837,  841,  845,  846,  848,  849,  850,
#         857,  860,  862,  863,  866,  870,  871,  874,  875,  877,  878,
#         881,  882,  883,  888,  889,  890,  891,  892,  894,  895,  897,
#         900,  901,  903,  906,  907,  908,  909,  916,  921,  925,  927,
#         929,  931,  933,  934,  938,  940,  942,  943,  946,  950,  954,
#         961,  963,  964,  965,  966,  968,  970,  971,  972,  975,  976,
#         977,  980,  982,  984,  989,  993,  994,  998, 1000, 1003, 1007,
#        1009, 1010, 1011, 1012, 1013, 1020, 1023, 1024, 1030, 1034, 1035,
#        1036, 1040, 1045, 1046, 1047, 1049, 1050, 1053, 1057, 1058, 1059,
#        1060, 1066, 1067, 1070, 1073, 1074, 1078, 1082, 1086])

# %%
# Get the images and labels
images = np.concatenate([x for x, y in test_dataset], axis=0)
incorrect_images = images[incorrect_indices]
incorrect_true_labels = y_true[incorrect_indices]
incorrect_pred_labels = y_pred_classes[incorrect_indices]

# %%
# Display incorrectly classified images
num_images_to_display = 10  # Number of images to display
plt.figure(figsize=(15, 15))
for i in range(min(num_images_to_display, len(incorrect_images))):
    plt.subplot(5, 2, i + 1)
    plt.imshow(incorrect_images[i].astype("uint8"))
    plt.title(f"True: {class_names[incorrect_true_labels[i]]}, Pred: {class_names[incorrect_pred_labels[i]]}")
    plt.axis("off")
plt.show()

# %% [markdown]
# leaf spot : Mature lesions from gray leaf spot are rectangular, as they are restricted by the leaf veins.
#
# leaf blight : Northern corn leaf blight is easily identified by the 1- to 6-inch cigar-shaped lesions on lower leaves, which may be grayish-green to tan in color.

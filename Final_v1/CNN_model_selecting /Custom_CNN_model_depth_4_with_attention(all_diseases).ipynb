# %% [markdown]
# <a href="https://colab.research.google.com/github/AchinthaThennakoon/L4S2-FYP-UOM/blob/main/Final_v1/CNN_model_selecting%20/Custom_CNN_model_depth_4_with_attention(all_diseases).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# %%
import pandas as pd

# %%
import pickle

# %%
import json
import os

# %%
import numpy as np

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# # loading data set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train'

# %%
data_dir = pathlib.Path(dataset_path)
data_dir
# Out:
# PosixPath('/content/drive/MyDrive/Colab Notebooks/FYP_code/Disease_dataset/Corn (Maize)/Train')

# %%
train_ds,val_ds =  keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.3,
    subset="both",
    seed=123,
    shuffle=True,
    batch_size=32,
    image_size=(224, 224),
    )
# Out:
# Found 7326 files belonging to 4 classes.
# Using 5129 files for training.
# Using 2197 files for validation.

# %%
for batch in train_ds.take(1):
    images, labels = batch
    print(images.shape)  # Should be (32, 224, 224, 3) if batch size is 32
    print(labels.shape)
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['Cercospora Leaf Spot', 'Common Rust', 'Healthy', 'Northern Leaf Blight']

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in train_ds.take(1):
    for i in range(8):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ## divide validation set to test & validation

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(val_ds))
# Out:
# Number of validation batches: 69

# %%
val_batches = tf.data.experimental.cardinality(val_ds)
test_dataset = val_ds.take(val_batches // 2)
validation_dataset = val_ds.skip(val_batches // 2)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 35
# Number of test batches: 34

# %% [markdown]
# # parameters and augmentations

# %%
resize_and_rescale = keras.Sequential([
  keras.layers.Resizing(224, 224),
  keras.layers.Rescaling(1./127.5, offset=-1),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2)
])

# %%
no_of_classes = len(class_names)
no_of_classes
# Out:
# 4

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS=3

# %%
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

# %%
epochs = 150

# %% [markdown]
# # Attention layer

# %%
@tf.keras.utils.register_keras_serializable()
class SpatialAttention(layers.Layer):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()
        self.conv = layers.Conv2D(filters=1, kernel_size=kernel_size, padding='same', activation='sigmoid')

    def call(self, inputs):
        avg_pool = tf.reduce_mean(inputs, axis=-1, keepdims=True)
        max_pool = tf.reduce_max(inputs, axis=-1, keepdims=True)
        concat = layers.Concatenate(axis=-1)([avg_pool, max_pool])
        attention_map = self.conv(concat)
        return inputs * attention_map

# %% [markdown]
# # model

# %%
def create_model():
    inputs = layers.Input(shape=input_shape)
    x = resize_and_rescale(inputs)
    x = data_augmentation(x)
    x = layers.Conv2D(32, kernel_size=(3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)

    # Add Spatial Attention layer here
    #x = SpatialAttention()(x)

    x = layers.Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Flatten()(x)
    x = layers.Dense(64, activation='relu')(x)
    outputs = layers.Dense(no_of_classes, activation='softmax')(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# %% [markdown]
# ## Early stopping

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
                                                    monitor='val_loss',
                                                    mode='min',
                                                    patience=5,
                                                    restore_best_weights=True
                                                    )

# %% [markdown]
# # Training, Save and evaluation functions

# %%
model_path = '/content/drive/MyDrive/Colab Notebooks/FYP_code/Final_v1/CNN_model_selecting/custom_CNN/models'

# %%
model = create_model()
history = model.fit(
                    train_ds,
                    batch_size=BATCH_SIZE,
                    validation_data=validation_dataset,
                    verbose=1,
                    epochs=epochs,
                    callbacks=[early_stopping]
                    )

model.save(os.path.join(model_path, f'custom_cnn_model_depth_{4}_all_diseases.keras'))
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential_2 (Sequential)   (None, 224, 224, 3)       0
#
#  sequential_3 (Sequential)   (None, 224, 224, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 222, 222, 32)      896
#
#  max_pooling2d_4 (MaxPoolin  (None, 111, 111, 32)      0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 52, 52, 64)        36928
#
#  max_pooling2d_6 (MaxPoolin  (None, 26, 26, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 64)        36928
#
#  max_pooling2d_7 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 64)                589888
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 683396 (2.61 MB)
# Trainable params: 683396 (2.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/150
# 161/161 [==============================] - 31s 169ms/step - loss: 0.4363 - accuracy: 0.8066 - val_loss: 0.2818 - val_accuracy: 0.8828
# Epoch 2/150
# 161/161 [==============================] - 30s 184ms/step - loss: 0.1944 - accuracy: 0.9228 - val_loss: 0.2233 - val_accuracy: 0.9080
# Epoch 3/150
# 161/161 [==============================] - 31s 190ms/step - loss: 0.1557 - accuracy: 0.9401 - val_loss: 0.1628 - val_accuracy: 0.9423
# Epoch 4/150
# 161/161 [==============================] - 30s 184ms/step - loss: 0.1221 - accuracy: 0.9540 - val_loss: 0.1338 - val_accuracy: 0.9495
# Epoch 5/150
# 161/161 [==============================] - 28s 167ms/step - loss: 0.1065 - accuracy: 0.9608 - val_loss: 0.1081 - val_accuracy: 0.9630
# Epoch 6/150
# 161/161 [==============================] - 32s 197ms/step - loss: 0.0981 - accuracy: 0.9626 - val_loss: 0.1022 - val_accuracy: 0.9657
# Epoch 7/150
# 161/161 [==============================] - 27s 165ms/step - loss: 0.1008 - accuracy: 0.9647 - val_loss: 0.1028 - val_accuracy: 0.9666
# Epoch 8/150
# 161/161 [==============================] - 28s 171ms/step - loss: 0.1147 - accuracy: 0.9587 - val_loss: 0.1136 - val_accuracy: 0.9576
# Epoch 9/150
# 161/161 [==============================] - 30s 182ms/step - loss: 0.0712 - accuracy: 0.9737 - val_loss: 0.0860 - val_accuracy: 0.9766
# Epoch 10/150
# 161/161 [==============================] - 30s 183ms/step - loss: 0.0745 - accuracy: 0.9731 - val_loss: 0.0885 - val_accuracy: 0.9729
# Epoch 11/150
# 161/161 [==============================] - 28s 170ms/step - loss: 0.0618 - accuracy: 0.9807 - val_loss: 0.1347 - val_accuracy: 0.9522
# Epoch 12/150
# 161/161 [==============================] - 28s 170ms/step - loss: 0.0684 - accuracy: 0.9745 - val_loss: 0.0754 - val_accuracy: 0.9784
# Epoch 13/150
# 161/161 [==============================] - 32s 195ms/step - loss: 0.0566 - accuracy: 0.9784 - val_loss: 0.0754 - val_accuracy: 0.9757
# Epoch 14/150
# 161/161 [==============================] - 32s 191ms/step - loss: 0.0560 - accuracy: 0.9807 - val_loss: 0.0634 - val_accuracy: 0.9811
# Epoch 15/150
# 161/161 [==============================] - 28s 167ms/step - loss: 0.0547 - accuracy: 0.9801 - val_loss: 0.0558 - val_accuracy: 0.9829
# Epoch 16/150
# 161/161 [==============================] - 28s 168ms/step - loss: 0.0586 - accuracy: 0.9787 - val_loss: 0.0490 - val_accuracy: 0.9847
# Epoch 17/150
# 161/161 [==============================] - 31s 186ms/step - loss: 0.0491 - accuracy: 0.9846 - val_loss: 0.0676 - val_accuracy: 0.9766
# Epoch 18/150
# 161/161 [==============================] - 32s 189ms/step - loss: 0.0448 - accuracy: 0.9856 - val_loss: 0.1447 - val_accuracy: 0.9711
# Epoch 19/150
# 161/161 [==============================] - 31s 187ms/step - loss: 0.0585 - accuracy: 0.9780 - val_loss: 0.0698 - val_accuracy: 0.9820
# Epoch 20/150
# 161/161 [==============================] - 30s 181ms/step - loss: 0.0464 - accuracy: 0.9850 - val_loss: 0.0830 - val_accuracy: 0.9793
# Epoch 21/150
# 161/161 [==============================] - 30s 180ms/step - loss: 0.0710 - accuracy: 0.9768 - val_loss: 0.0676 - val_accuracy: 0.9802

# %%
test_loss, test_acc = model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 4s 111ms/step - loss: 0.0550 - accuracy: 0.9825

# %%
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# Test accuracy: 0.982536792755127
# Test loss: 0.05500015988945961

# %% [markdown]
# # loading model(if needed)

# %%
#model = create_model()

# %%
#model = tf.keras.models.load_model(os.path.join(model_path, f'custom_cnn_model_depth_{4}_all_diseases.keras'))

# %% [markdown]
# # predictions

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 4s 112ms/step - loss: 0.0550 - accuracy: 0.9825
# [0.05500015988945961, 0.982536792755127]

# %%
predictions = model.predict(test_dataset)
# Out:
# 34/34 [==============================] - 5s 140ms/step

# %%
predictions
# Out:
# array([[9.9979287e-01, 8.8578425e-05, 7.7037157e-08, 1.1856289e-04],
#        [8.8236861e-13, 1.0000000e+00, 5.3264367e-25, 1.8966099e-15],
#        [3.9128503e-03, 2.6483985e-06, 6.3139014e-09, 9.9608445e-01],
#        ...,
#        [7.5879201e-05, 1.9758352e-04, 9.9965692e-01, 6.9617920e-05],
#        [7.0154533e-02, 6.5078569e-04, 9.7596858e-05, 9.2909712e-01],
#        [1.2578129e-14, 1.0000000e+00, 2.1378040e-26, 2.8641381e-18]],
#       dtype=float32)

# %%
y_pred_classes = np.argmax(predictions, axis=1)
y_pred_classes
# Out:
# array([0, 1, 3, ..., 2, 3, 1])

# %%
y_true = np.concatenate([y for x, y in test_dataset], axis=0)
y_true
# Out:
# array([0, 1, 3, ..., 2, 3, 1], dtype=int32)

# %%
import collections
counter = collections.Counter(y_true)
print(counter)

# %%
cm = confusion_matrix(y_true, y_pred_classes)

# Create a larger figure
fig, ax = plt.subplots(figsize=(10, 10))

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, ax=ax)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
#                       precision    recall  f1-score   support
#
# Cercospora Leaf Spot       0.97      0.96      0.96       227
#          Common Rust       0.99      1.00      0.99       295
#              Healthy       0.99      1.00      1.00       269
# Northern Leaf Blight       0.97      0.97      0.97       297
#
#             accuracy                           0.98      1088
#            macro avg       0.98      0.98      0.98      1088
#         weighted avg       0.98      0.98      0.98      1088

# %% [markdown]
# # show incorrectly classified images

# %%
# Find incorrectly classified images
incorrect_indices = np.where(y_pred_classes != y_true)[0]
incorrect_indices
# Out:
# array([  62,  133,  177,  288,  306,  345,  426,  428,  463,  501,  616,
#         660,  731,  742,  779,  872,  934, 1036, 1049])

# %%
# Get the images and labels
images = np.concatenate([x for x, y in test_dataset], axis=0)
incorrect_images = images[incorrect_indices]
incorrect_true_labels = y_true[incorrect_indices]
incorrect_pred_labels = y_pred_classes[incorrect_indices]

# %%
# Display incorrectly classified images
num_images_to_display = 10  # Number of images to display
plt.figure(figsize=(15, 15))
for i in range(min(num_images_to_display, len(incorrect_images))):
    plt.subplot(5, 2, i + 1)
    plt.imshow(incorrect_images[i].astype("uint8"))
    plt.title(f"True: {class_names[incorrect_true_labels[i]]}, Pred: {class_names[incorrect_pred_labels[i]]}")
    plt.axis("off")
plt.show()

# %% [markdown]
# leaf spot : Mature lesions from gray leaf spot are rectangular, as they are restricted by the leaf veins.
#
# leaf blight : Northern corn leaf blight is easily identified by the 1- to 6-inch cigar-shaped lesions on lower leaves, which may be grayish-green to tan in color.
